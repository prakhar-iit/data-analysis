# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd 
import selenium.webdriver

# %%
star_5_website_url = "https://www.makemytrip.com/hotels/hotel-listing/?_uCurrency=INR&checkin=06292020&checkout=06302020&city=RGTRV&country=IN&filterData=STAR_RATING%7C5&locusId=RGTRV&locusType=region&reference=hotel&roomStayQualifier=2e0e&searchText=Thiruvananthapuram%20District%2C%20Kerala%2C%20India&type=region"
star_4_website_URL = "https://www.makemytrip.com/hotels/hotel-listing/?_uCurrency=INR&checkin=06292020&checkout=06302020&city=RGTRV&country=IN&filterData=STAR_RATING%7C4&locusId=RGTRV&locusType=region&reference=hotel&roomStayQualifier=2e0e&searchText=Thiruvananthapuram%20District%2C%20Kerala%2C%20India&type=region"
star_3_website_URL = "https://www.makemytrip.com/hotels/hotel-listing/?_uCurrency=INR&checkin=06292020&checkout=06302020&city=RGTRV&country=IN&filterData=STAR_RATING%7C3&locusId=RGTRV&locusType=region&reference=hotel&roomStayQualifier=2e0e&searchText=Thiruvananthapuram%20District%2C%20Kerala%2C%20India&type=region"

# %%
url = "https://www.makemytrip.com/hotels/hotel-listing/?_uCurrency=INR&checkin=11072020&checkout=11082020&city=CTGOI&country=IN&locusId=CTGOI&locusType=city&roomStayQualifier=2e0e&searchText=Goa%2C%20India&visitorId=12806057-93f1-4fa3-b618-c1bf46e18ad7"

# %%
headers = requests.utils.default_headers()

# %%
#headers.update({
#    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
#})

headers.update({
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36',
})

# %%
response = requests.request("GET", url, headers = headers)

data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=5" name="viewport"/>
# <meta content="#FFF" name="theme-color">
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="//imgak.mmtcdn.com" rel="dns-prefetch"/>
# <link href="//jsak.mmtcdn.com" rel="dns-prefetch"/>
# <link href="//imgak.mmtcdn.com" rel="preconnect"/>
# <link href="//jsak.mmtcdn.com" rel="preconnect"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,900&amp;display=swap" onload="this.rel = 'stylesheet'" rel="preload">
# <link as="script" href="//jsak.mmtcdn.com/pwa_v3/pwa_hotel/js/webpackManifest.e8db565c.js" rel="preload"/>
# <link as="script" href="//jsak.mmtcdn.com/pwa_v3/pwa_hotel/js/vendor.e8db565c.js" rel="preload"/>
# ...

# %%
driver = selenium.webdriver.Chrome()
driver.get(url)  			 # URL requested in browser.
for j in range(1, 500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
soup = BeautifulSoup(body)
tags = soup.find_all("div", {"class": "listingRowOuter"})

hotels = []
address = []
for tag in tags:
    hotels.append(tag.find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
    address.append(tag.find('a').find_all('p', itemprop="address")[0].text)

driver.quit()

#dict = {'Hotels':  hotels, 
#       'Address': address}

#df = pd.DataFrame(dict)
#df.to_csv('4starHotels.csv')

print("hotels : ", hotels)
print("address : ", address)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-10-63b6a49836f0> in <module>
# ----> 1 driver = selenium.webdriver.Chrome()
#       2 driver.get(url)                          # URL requested in browser.
#       3 for j in range(1, 500):
#       4     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium-4.0.0a5-py3.7.egg/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      65                                         port, options,
#      66                                         service_args, desired_capabilities,
# ---> 67                                         service_log_path, service, keep_alive)
#      68
# ...

# %%
driver = selenium.webdriver.Chrome()
driver.get(url)  			 # URL requested in browser.
for j in range(1, 500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
soup =BeautifulSoup(body)
tags = soup.find_all("div", {"class": "listingRowOuter"})

hotels = []
address = []
for tag in tags:
    hotels.append(tag.find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
    address.append(tag.find('a').find_all('p', itemprop="address")[0].text)

driver.quit()

dict = {'Hotels':  hotels, 
       'Address': address}

df = pd.DataFrame(dict)
df.to_csv('5starHotels.csv')
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-6-067dfb059277> in <module>
# ----> 1 driver = selenium.webdriver.Chrome()
#       2 driver.get(url)                          # URL requested in browser.
#       3 for j in range(1, 500):
#       4     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium-4.0.0a5-py3.7.egg/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      65                                         port, options,
#      66                                         service_args, desired_capabilities,
# ---> 67                                         service_log_path, service, keep_alive)
#      68
# ...

# %%
driver = selenium.webdriver.Chrome()
driver.get(star_3_website_URL)  			 # URL requested in browser.
for j in range(1, 5000):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
soup =BeautifulSoup(body)
tags = soup.find_all("div", {"class": "listingRowOuter"})

hotels = []
address = []
for tag in tags:
    hotels.append(tag.find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
    address.append(tag.find('a').find_all('p', itemprop="address")[0].text)

driver.quit()

dict = {'Hotels':  hotels, 
       'Address': address}

df = pd.DataFrame(dict)
df.to_csv('3starHotels.csv')

# %%
tags[0].find('a').find_all('p', itemprop="address")[0].text
# Out:
# 'Thiruvanmiyur'

# %%
print(tags[0].find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d15f08858571> in <module>
# ----> 1 print(tags[0].find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
#
# NameError: name 'tags' is not defined

# %%
tags = soup.find_all("div", {"class": "listingRowOuter"})
#tags = soup.find_all("a", href=True)

# %%
hotels = []
address = []
for tag in tags:
    hotels.append(tag.find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
    address.append(tag.find('a').find_all('p', itemprop="address")[0].text)

# %%
dict = {'Hotels':  hotels, 
       'Address': address}

# %%
hotel_url ="https://www.makemytrip.com/hotels/hotel-details/?hotelId=20161004171331874&mtkeys=defaultMtkey&_uCurrency=INR&checkin=05052020&checkout=05062020&city=CTMAA&country=IN&filterData=STAR_RATING%7C5&lat=12.980501&lng=80.252975&locusId=CTMAA&locusType=city&rank=1&roomStayQualifier=2e0e&searchText=Chennai%2C%20Tamil%20Nadu%2C%20India&visitorId=9e3852e0-4e14-4b50-8625-d0c462dad288"

# %%
Link_hotel = requests.get(hotel_url, headers=headers)

# %%
Link_hotel
# Out:
# <Response [200]>

# %%
soup_hotel =BeautifulSoup(Link.content,"lxml")

# %%
hotel_str = soup_hotel.find_all("script")[4].text.replace("window.__INITIAL_STATE__ = ", "")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-232-25cc293dec50> in <module>
#       1 hotel_str = soup_hotel.find_all("script")[4].text.replace("window.__INITIAL_STATE__ = ", "")
# ----> 2 hotel_str = dict(hotel_str)
#       3 print(hotel_str)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
import json

# %%
data = str(soup_hotel.find_all("script")[4])

# %%
cut = json.loads(hotel_str)

# %%
cut['hotelDetail']
# Out:
# {'showPriceLoader': False,
#  'markerDataSelectedOnMap': None,
#  'selectedMarkerType': 'P',
#  'showingInfoWindow': False,
#  'searchPriceRequestState': {'loading': False,
#   'error': None,
#   'success': False},
#  'hotelStaticDetailsRequestState': {'loading': False,
#   'error': None,
#   'success': False}}

# %%
driver = selenium.webdriver.Chrome()
driver.get(website_url)  			 # URL requested in browser.
for j in range(1, 500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
soup =BeautifulSoup(body)
# Out:
# /Users/prakrast/opt/anaconda3/lib/python3.7/site-packages/selenium-4.0.0a5-py3.7.egg/selenium/webdriver/remote/webdriver.py:581: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")

# %%
tags = soup.find_all("div", {"class": "listingRowOuter"})
len(tags)
# Out:
# 22

# %%
#Link = requests.get(website_url, headers=headers)
#soup =BeautifulSoup(Link.content,"lxml")
#tags = soup.find_all("div", {"class": "listingRowOuter"})
#for tag in tags:
#        print(tag.find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
# Out:
# Holiday Inn Chennai OMR IT Expressway
# Trident Chennai
# Radisson Blu Hotel GRT Chennai
# Novotel Chennai OMR - An AccorHotels Brand
# Taj Connemara

# %%
driver.quit()

# %%
import pandas as pd

# %%
for tag in tags:
        print(tag.find('a').find_all('p', id="hlistpg_hotel_name")[0].find('span').text)
# Out:
# Holiday Inn Chennai OMR IT Expressway
# Trident Chennai
# Radisson Blu Hotel GRT Chennai
# Novotel Chennai OMR - An AccorHotels Brand
# Taj Connemara
# The Leela Palace Chennai
# Hilton Chennai
# The Raintree St. Marys Road
# Taj Club House
# Turyaa Chennai
# Citadines OMRChennai
# Radisson Blu Hotel Chennai City Centre
# Taj Coromandel
# Le Royal Meridien
# Hyatt Regency Chennai
# Feathers A Radha Hotel Chennai
# Novotel Chennai Chamiers Road
# Novotel Chennai Sipcot - An AccorHotels Brand
# Mercure Chennai Sriperumbudur - An Accorhotels Brand
# Vivanta Chennai IT Expressway
# Green Park Chennai
# Grand Beach Home Stay

# %%
df = pd.DataFrame(dict)

# %%
df.to_csv('5starHotels.csv')
